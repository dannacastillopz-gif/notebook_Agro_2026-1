# %% [markdown]
# <a href="https://colab.research.google.com/github/dannacastillopz-gif/notebook_Agro_2026-1/blob/main/Notebook_semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ENTRADA:Entra ancho y alto de la madera en metros
ancho = input("incresa el ancho de la ventana en metros")
ancho = float(ancho)
alto = input("incresa el alto de la ventana en metros")
alto = float (alto)

# PROCESO: calcular longitud de la amdera (lm) en pies y el area del vidrio en metro

lm=2*(ancho+alto)*3.25
av=2*(ancho*alto)

# SALIDA: sale la longitud de la madera en pies
# el area del vidrio en metros cuadrados
print ("longitud de la madera es ",lm, "pies de longitud")
print("el area del vidrio es ", av, "metros cuadrados")
# Out:
# incresa el ancho de la ventana en metros1
# incresa el alto de la ventana en metros2
# longitud de la madera es  19.5 pies de longitud
# el area del vidrio es  4.0 metros cuadrados
